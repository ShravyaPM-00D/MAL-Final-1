# %% [markdown]
# # MICROPROJECT - Sample Solution
#
# This is a reference solution showing best practices.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1: Load and Explore Data

# %%
from sklearn.datasets import load_iris
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
print(df.head())
print(df.describe())

# %% [markdown]
# ## Step 2: Visualize Data

# %%
plt.scatter(df.iloc[:, 0], df.iloc[:, 1])
plt.xlabel(df.columns[0])
plt.ylabel(df.columns[1])
plt.show()

# %% [markdown]
# ## Summary
#
# Key findings and learnings from this project.
